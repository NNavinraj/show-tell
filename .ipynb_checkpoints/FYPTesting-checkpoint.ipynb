# %%
from os import listdir
from pickle import dump
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model

i = 0;
# extract features from each photo in the directory
def extract_features(directory):
	global i
	# load the model
	model = VGG16()
	# re-structure the model
	model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
	# summarize
	print(model.summary())
	# extract features from each photo
	features = dict()
	for name in listdir(directory):
		# load an image from file
		filename = directory + '/' + name
		image = load_img(filename, target_size=(224, 224))
		# convert the image pixels to a numpy array
		image = img_to_array(image)
		# reshape data for the model
		image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
		# prepare the image for the VGG model
		image = preprocess_input(image)
		# get features
		feature = model.predict(image, verbose=0)
		# get image id
		image_id = name.split('.')[0]
		# store feature
		features[image_id] = feature
		#print('>%s' % name, "#0", "Round Head With Short Folded Ears")
		print('>%s' % name)
		
		#if(i >= 81):
			#print('>%s' % name,"#0","Short fur With Round Face")
			#i += 1
			
		#else:
			#print('>%s' % name,"#0","Short fur With Grumpy Face")
			#i += 1

	return features

# extract features from all images
directory = r'C:\Users\14059174\Desktop\FYP\Image Dataset\Cat Dataset Summary\Train'
features = extract_features(directory)
print('Extracted Features: %d' % len(features))
# save to file
dump(features, open('features.pkl', 'wb'))
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________
# None
# >12826085_3367.jpg
# >14171357_3289.jpg
# >15243545_1553.jpg
# >16701577_727.jpg
# >17084365_3070.jpg
# >17653895_843.jpg
# >17764345_713.jpg
# >17832243_2994.jpg
# >17911833_836.jpg
# >17936890_2984.jpg
# >18096830_833.jpg
# >18306838_1405.jpg
# >18321465_2937.jpg
# >18350950_2933.jpg
# >18359263_2931.jpg
# >18367948_2930.jpg
# >18402297_702.jpg
# >18402327_701.jpg
# >18413850_700.jpg
# >18417441_827.jpg
# >18452560_2919.jpg
# >18455978_699.jpg
# >18461154_825.jpg
# >18483168_1392.jpg
# >18489017_2914.jpg
# >18518409_2908.jpg
# >18519464_2907.jpg
# >18522149_697.jpg
# >18610728_691.jpg
# >18635257_2899.jpg
# >18636249_2896.jpg
# >18648738_818.jpg
# >18688182_2889.jpg
# >18761590_2882.jpg
# >18800358_2878.jpg
# >18800384_2877.jpg
# >18808260_688.jpg
# >18842478_2872.jpg
# >18845597_809.jpg
# >18881261_2866.jpg
# >18911781_807.jpg
# >19020771_2860.jpg
# >19048947_2857.jpg
# >19093020_2854.jpg
# >19136173_800.jpg
# >19158672_2849.jpg
# >19233738_796.jpg
# >19306234_2843.jpg
# >19341223_2838.jpg
# >19387548_1355.jpg
# >19529283_2819.jpg
# >19541667_2818.jpg
# >19570866_787.jpg
# >19626827_2810.jpg
# >19661545_786.jpg
# >19661613_674.jpg
# >19739928_784.jpg
# >19769478_1349.jpg
# >19776082_1348.jpg
# >19781645_673.jpg
# >19793423_782.jpg
# >19894210_672.jpg
# >19923910_1343.jpg
# >19985480_669.jpg
# >20023679_668.jpg
# >20039287_2778.jpg
# >20121462_2772.jpg
# >20191932_2765.jpg
# >20192296_1334.jpg
# >20275271_2757.jpg
# >20292356_2753.jpg
# >20351846_2749.jpg
# >20406752_1327.jpg
# >20406774_1326.jpg
# >20425097_658.jpg
# >20472846_2737.jpg
# >20558980_657.jpg
# >20604944_1319.jpg
# >20641272_2727.jpg
# >20694169_1316.jpg
# >20722583_1315.jpg
# >20726943_1314.jpg
# >20770811_2715.jpg
# >20826386_2709.jpg
# >20826727_1308.jpg
# >20827403_2708.jpg
# >20843463_760.jpg
# >20854686_759.jpg
# >20861235_2704.jpg
# >20882623_2699.jpg
# >20890482_2698.jpg
# >20917734_757.jpg
# >20925339_2694.jpg
# >20950941_756.jpg
# >20964739_1295.jpg
# >20965591_2692.jpg
# >21005679_754.jpg
# >21071159_2688.jpg
# >21074867_2686.jpg
# >21099632_753.jpg
# >21125243_1285.jpg
# >21151316_752.jpg
# >21151349_751.jpg
# >21172512_749.jpg
# >21172555_748.jpg
# >21208533_2674.jpg
# >21239628_1280.jpg
# >21245302_1278.jpg
# >21265257_2670.jpg
# >21292333_2666.jpg
# >21297343_2664.jpg
# >21312256_1276.jpg
# >21367961_1275.jpg
# >21378356_2655.jpg
# >21391778_742.jpg
# >21529243_1272.jpg
# >21530703_737.jpg
# >21546457_1269.jpg
# >21569902_735.jpg
# >21575731_734.jpg
# >21601926_1265.jpg
# >21679994_732.jpg
# >21713589_1260.jpg
# >21749893_2615.jpg
# >21777212_2608.jpg
# >21783060_2607.jpg
# >21861200_2601.jpg
# >21866531_2598.jpg
# >21869210_729.jpg
# >21869240_728.jpg
# >21878610_1255.jpg
# >21881673_2591.jpg
# >21894528_2590.jpg
# >21906554_2588.jpg
# >21946436_2584.jpg
# >21989300_2576.jpg
# >21997614_726.jpg
# >22022781_2572.jpg
# >22072340_1243.jpg
# >22117070_2556.jpg
# >22143067_2552.jpg
# >22196841_603.jpg
# >22209626_2547.jpg
# >22228772_2542.jpg
# >22239123_1239.jpg
# >22240353_2541.jpg
# >22258950_1238.jpg
# >22268887_2533.jpg
# >22291604_2529.jpg
# >22313382_2526.jpg
# >22338280_2521.jpg
# >22383924_722.jpg
# >22391382_2513.jpg
# >22405237_1232.jpg
# >22447863_2502.jpg
# >22487677_2499.jpg
# >22515335_1226.jpg
# >22515369_1225.jpg
# >22533686_2492.jpg
# >22564906_2490.jpg
# >22578411_2487.jpg
# >22630399_2478.jpg
# >22641854_1217.jpg
# >22691835_1215.jpg
# >22823841_2463.jpg
# >22825059_1210.jpg
# >22826295_589.jpg
# >22890300_2459.jpg
# >22892749_1208.jpg
# >22893136_586.jpg
# >22906796_2457.jpg
# >22913322_2455.jpg
# >22919121_1207.jpg
# >22923011_712.jpg
# >22934358_2453.jpg
# >22962917_2447.jpg
# >22963450_2446.jpg
# >22963472_2445.jpg
# >22967897_711.jpg
# >22977925_1205.jpg
# >23022100_2437.jpg
# >23063102_2434.jpg
# >23070406_2432.jpg
# >23072402_1200.jpg
# >23100034_2426.jpg
# >23109953_707.jpg
# >23152673_1199.jpg
# >23158464_705.jpg
# >23158560_704.jpg
# >23174342_2419.jpg
# >23217827_701.jpg
# >23222513_2415.jpg
# >23245530_574.jpg
# >23248161_1195.jpg
# >23336868_2411.jpg
# >23369499_2405.jpg
# >23386537_2399.jpg
# >23436128_698.jpg
# >23443211_2393.jpg
# >23486493_2392.jpg
# >23612364_563.jpg
# >23614790_1177.jpg
# >23614839_2376.jpg
# >23631453_2372.jpg
# >23700349_559.jpg
# >23757461_2360.jpg
# >23783705_1168.jpg
# >23783715_1167.jpg
# >23786800_1166.jpg
# >23789316_2357.jpg
# >23870350_1159.jpg
# >23921085_2350.jpg
# >24323537_2323.jpg
# >24360847_2318.jpg
# >24448485_2308.jpg
# >24449476_2307.jpg
# >24451487_657.jpg
# >24585938_2287.jpg
# >24588836_2286.jpg
# >24613722_2281.jpg
# >24658301_2277.jpg
# >24679228_646.jpg
# >24681282_535.jpg
# >24689692_645.jpg
# >24689831_644.jpg
# >24715557_643.jpg
# >24726852_2268.jpg
# >24737845_642.jpg
# >24866138_2248.jpg
# >24881734_2245.jpg
# >24884236_636.jpg
# >24887180_528.jpg
# >24891401_2243.jpg
# >24922994_2239.jpg
# >24932262_633.jpg
# >24941905_2236.jpg
# >24961335_2233.jpg
# >24976643_2230.jpg
# >24992979_2228.jpg
# >25007392_630.jpg
# >25020536_2218.jpg
# >25047802_2209.jpg
# >25049506_2207.jpg
# >25070860_625.jpg
# >25110209_2200.jpg
# >25113976_516.jpg
# >25122047_2197.jpg
# >25125478_2195.jpg
# >25131380_2194.jpg
# >25148220_2189.jpg
# >25167056_2186.jpg
# >25172524_510.jpg
# >25253153_2178.jpg
# >25260741_620.jpg
# >25276539_618.jpg
# >25299558_616.jpg
# >25317738_2161.jpg
# >25323694_614.jpg
# >25323752_613.jpg
# >25325096_2157.jpg
# >25334786_2153.jpg
# >25404944_2148.jpg
# >25406075_609.jpg
# >25430941_2145.jpg
# >25431862_608.jpg
# >25436094_2144.jpg
# >25464202_503.jpg
# >25464388_2139.jpg
# >25506249_2133.jpg
# >25563845_2127.jpg
# >25613502_2119.jpg
# >25687961_2107.jpg
# >25707527_2106.jpg
# >25716108_603.jpg
# >25749161_2101.jpg
# >25763914_2100.jpg
# >25774967_2097.jpg
# >25779437_496.jpg
# >25788287_2094.jpg
# >25811780_2087.jpg
# >25863750_2080.jpg
# >25871672_2078.jpg
# >25945734_2071.jpg
# >26068601_2057.jpg
# >26080737_601.jpg
# >26174793_599.jpg
# >26176364_2043.jpg
# >26190279_2038.jpg
# >26190895_490.jpg
# >26198827_2037.jpg
# >26204836_2035.jpg
# >26254831_598.jpg
# >26314518_486.jpg
# >26395082_2020.jpg
# >26409511_2018.jpg
# >26454040_2012.jpg
# >26502726_2008.jpg
# >26530726_588.jpg
# >26548681_2003.jpg
# >26595346_2001.jpg
# >26605454_2000.jpg
# >26615614_586.jpg
# >26699082_581.jpg
# >26766092_1991.jpg
# >26784759_580.jpg
# >26796565_579.jpg
# >26869781_1978.jpg
# >26894711_1976.jpg
# >26922278_1972.jpg
# >26937878_575.jpg
# >26998020_1969.jpg
# >27148487_563.jpg
# >27174108_562.jpg
# >27174176_561.jpg
# >27197527_1957.jpg
# >27302913_1950.jpg
# >27321211_1944.jpg
# >27333499_1941.jpg
# >27357907_1940.jpg
# >27435537_1932.jpg
# >27454903_1930.jpg
# >27460252_1929.jpg
# >27530493_1923.jpg
# >27637528_1916.jpg
# >27637544_1915.jpg
# >27700726_1910.jpg
# >27758846_1908.jpg
# >27762074_1903.jpg
# >27777571_1899.jpg
# >27896670_452.jpg
# >27896680_451.jpg
# >27912401_1885.jpg
# >27937720_1881.jpg
# >27961514_1878.jpg
# >27985568_1873.jpg
# >28053607_1862.jpg
# >28064062_448.jpg
# >28200097_1837.jpg
# >28301118_1825.jpg
# >28317793_1823.jpg
# >28343947_1817.jpg
# >28355507_430.jpg
# >28377489_1807.jpg
# >28428913_1798.jpg
# >28428950_1797.jpg
# >28445291_1791.jpg
# >28448434_1788.jpg
# >28459148_1785.jpg
# >28474710_1783.jpg
# >28560894_1769.jpg
# >28594846_1765.jpg
# >28647685_1757.jpg
# >28667461_1752.jpg
# >28704535_1747.jpg
# >28824544_518.jpg
# >28828705_1735.jpg
# >28862143_1732.jpg
# >28869518_517.jpg
# >28887491_1726.jpg
# >28890372_1725.jpg
# >28897305_510.jpg
# >28897333_509.jpg
# >28897357_508.jpg
# >28897383_507.jpg
# >28898215_506.jpg
# >28916071_505.jpg
# >28916121_504.jpg
# >28931772_1719.jpg
# >28998123_1713.jpg
# >29083137_1708.jpg
# >29092170_1706.jpg
# >29108942_1703.jpg
# >29125177_1702.jpg
# >29199605_1695.jpg
# >29294963_1682.jpg
# >29339098_869.jpg
# >29361068_1672.jpg
# >29398114_1670.jpg
# >29469359_862.jpg
# >29470166_1663.jpg
# >29493295_1661.jpg
# >29499548_861.jpg
# >29521265_1659.jpg
# >29584818_1649.jpg
# >29584837_1648.jpg
# >29584920_1647.jpg
# >29597704_1645.jpg
# >29597751_1644.jpg
# >29597854_1643.jpg
# >29601414_860.jpg
# >29624017_1640.jpg
# >29642975_859.jpg
# >29770853_854.jpg
# >29931606_848.jpg
# >30029269_1597.jpg
# >30205820_835.jpg
# >30224663_1582.jpg
# >30238254_1578.jpg
# >30286454_1572.jpg
# >30330513_1568.jpg
# >30348288_1566.jpg
# >30399364_1560.jpg
# >30790812_800.jpg
# >30807524_796.jpg
# >31020144_1474.jpg
# >31020155_1473.jpg
# >31129390_1458.jpg
# >31171146_777.jpg
# >31180464_1454.jpg
# >31226007_1449.jpg
# >31236165_1447.jpg
# >31242195_1445.jpg
# >31250852_1443.jpg
# >31278908_1438.jpg
# >31281187_1436.jpg
# >31281199_1434.jpg
# >31291066_1432.jpg
# >31314544_1429.jpg
# >31349441_1424.jpg
# >31349448_1423.jpg
# >31384920_1418.jpg
# >31404251_1417.jpg
# >31442414_1406.jpg
# >31449746_1405.jpg
# >31465271_1402.jpg
# >31481876_1401.jpg
# >31481891_1400.jpg
# >31514392_754.jpg
# >31533943_1393.jpg
# >31544650_1390.jpg
# >31650965_750.jpg
# >31724188_1375.jpg
# >31724232_1374.jpg
# >31735567_1371.jpg
# >31836526_1360.jpg
# >31850117_1358.jpg
# >31867775_1355.jpg
# >31898911_1353.jpg
# >31951674_1349.jpg
# >31965738_1348.jpg
# >32063961_1337.jpg
# >32115252_1333.jpg
# >32182849_1327.jpg
# >32230589_1320.jpg
# >32240038_1319.jpg
# >32246182_1316.jpg
# >32250464_1314.jpg
# >32262535_1311.jpg
# >32313087_1306.jpg
# >32368567_1304.jpg
# >32368574_1303.jpg
# >32368581_1302.jpg
# >32368598_1301.jpg
# >32368878_1297.jpg
# >32395177_1294.jpg
# >32440096_1292.jpg
# >32490928_1287.jpg
# >32714781_1269.jpg
# >32743054_1265.jpg
# >32792677_1262.jpg
# >32924076_1255.jpg
# >32961590_1250.jpg
# >33186772_1236.jpg
# >33197649_1235.jpg
# >33239739_1233.jpg
# >33268357_1227.jpg
# >33339903_1216.jpg
# >33345849_1214.jpg
# >33429467_1210.jpg
# >33490750_303.jpg
# >33574031_1190.jpg
# >33669069_1184.jpg
# >33742594_1177.jpg
# >33785459_1172.jpg
# >33792091_1171.jpg
# >33894732_1163.jpg
# >33907525_1161.jpg
# >33926307_1158.jpg
# >33931590_1157.jpg
# >33964940_1155.jpg
# >33965176_1154.jpg
# >33996484_1147.jpg
# >34013028_1143.jpg
# >34013072_1142.jpg
# >34020805_1141.jpg
# >34081661_1132.jpg
# >34132666_1125.jpg
# >34138811_1121.jpg
# >34144799_1119.jpg
# >34162774_1115.jpg
# >34257127_1109.jpg
# >34356224_1098.jpg
# >34370181_344.jpg
# >34408565_1093.jpg
# >34413045_1087.jpg
# >34454736_1080.jpg
# >34471563_340.jpg
# >34471866_339.jpg
# >34503050_1070.jpg
# >34571247_338.jpg
# >34599855_1063.jpg
# >34600030_1062.jpg
# >34600055_1061.jpg
# >34614894_619.jpg
# >34663279_336.jpg
# >34682212_1051.jpg
# >34725212_1043.jpg
# >34746042_611.jpg
# >34746131_610.jpg
# >34751936_1040.jpg
# >34756995_1039.jpg
# >34795079_1036.jpg
# >34822055_1034.jpg
# >34822103_1033.jpg
# >34822160_1032.jpg
# >34829672_1029.jpg
# >34840691_606.jpg
# >34849990_1027.jpg
# >34869252_1024.jpg
# >34900019_334.jpg
# >34937445_603.jpg
# >34981633_1015.jpg
# >35006210_1011.jpg
# >35006215_1010.jpg
# >35098094_997.jpg
# >35115876_595.jpg
# >35123599_252.jpg
# >35126236_328.jpg
# >35133981_992.jpg
# >35147798_990.jpg
# >35153191_989.jpg
# >35163897_988.jpg
# >35183040_326.jpg
# >35183422_325.jpg
# >35190246_985.jpg
# >35225477_248.jpg
# >35241867_593.jpg
# >35297064_977.jpg
# >35326649_974.jpg
# >35326666_973.jpg
# >35429691_964.jpg
# >35431395_590.jpg
# >35448338_960.jpg
# >35463639_959.jpg
# >35503819_955.jpg
# >35520411_951.jpg
# >35563955_585.jpg
# >35570905_947.jpg
# >35708013_935.jpg
# >35736109_932.jpg
# >35773891_925.jpg
# >35812665_920.jpg
# >35830373_918.jpg
# >35886847_911.jpg
# >35970610_906.jpg
# >35970645_905.jpg
# >35993319_903.jpg
# >36020477_897.jpg
# >36020530_896.jpg
# >36110772_890.jpg
# >36145430_887.jpg
# >36196417_884.jpg
# >36209212_883.jpg
# >36260610_292.jpg
# >36267576_876.jpg
# >36295106_874.jpg
# >36298440_233.jpg
# >36300152_873.jpg
# >36360556_865.jpg
# >36420289_862.jpg
# >36480223_849.jpg
# >36489788_286.jpg
# >36668292_826.jpg
# >36790566_276.jpg
# >36796320_821.jpg
# >36816410_275.jpg
# >36816415_274.jpg
# >36866783_815.jpg
# >36884845_272.jpg
# >36897425_810.jpg
# >36918166_271.jpg
# >36932195_805.jpg
# >36949717_802.jpg
# >36986018_797.jpg
# >36986619_796.jpg
# >37013248_794.jpg
# >37109879_787.jpg
# >37128112_783.jpg
# >37178656_776.jpg
# >37198579_775.jpg
# >37243276_263.jpg
# >37278895_764.jpg
# >37297917_762.jpg
# >37321759_261.jpg
# >37328239_759.jpg
# >37328351_758.jpg
# >37365589_756.jpg
# >37405136_755.jpg
# >37443685_751.jpg
# >37451016_750.jpg
# >37451924_260.jpg
# >37476504_257.jpg
# >37494697_748.jpg
# >37711053_732.jpg
# >37718995_730.jpg
# >37743947_729.jpg
# >37773175_725.jpg
# >37828703_255.jpg
# >37869810_716.jpg
# >37937805_709.jpg
# >37969166_710.jpg
# >37971430_704.jpg
# >38026330_698.jpg
# >38074548_252.jpg
# >38093738_693.jpg
# >38097797_692.jpg
# >38132829_251.jpg
# >38435873_247.jpg
# >38478699_657.jpg
# >38478740_656.jpg
# >38534805_246.jpg
# >38593867_650.jpg
# >38728327_234.jpg
# >38760546_637.jpg
# >38803008_636.jpg
# >38853397_635.jpg
# >38901881_632.jpg
# >38965504_627.jpg
# >39134611_616.jpg
# >39267569_613.jpg
# >39267596_612.jpg
# >39267618_611.jpg
# >39267651_609.jpg
# >39267705_608.jpg
# >39292653_607.jpg
# >39321429_604.jpg
# >39426303_593.jpg
# >39442083_590.jpg
# >39640501_579.jpg
# >39673478_166.jpg
# >39688253_575.jpg
# >39848685_556.jpg
# >39848737_555.jpg
# >39948719_544.jpg
# >40021999_540.jpg
# >40022023_539.jpg
# >40131003_404.jpg
# >40131964_402.jpg
# >40170900_401.jpg
# >40219062_396.jpg
# >40221456_526.jpg
# >40433123_393.jpg
# >40503637_392.jpg
# >40562323_523.jpg
# >40571655_519.jpg
# >40571657_518.jpg
# >40599827_516.jpg
# >40637814_513.jpg
# >40637946_512.jpg
# >40913059_489.jpg
# >40957045_352.jpg
# >40990716_484.jpg
# >41030954_477.jpg
# >41077408_470.jpg
# >41102400_467.jpg
# >41174243_460.jpg
# >41207915_340.jpg
# >41423982_441.jpg
# >41583656_427.jpg
# >41586219_426.jpg
# >41598130_425.jpg
# >41624891_319.jpg
# >41713145_416.jpg
# >41753917_411.jpg
# >41770303_403.jpg
# >41852461_398.jpg
# >42072067_378.jpg
# >42158627_375.jpg
# >42221048_366.jpg
# >42291580_363.jpg
# >42394514_354.jpg
# >42585061_342.jpg
# >42889466_330.jpg
# >42938865_325.jpg
# >43113423_310.jpg
# >43305138_302.jpg
# >43367105_294.jpg
# >43509761_280.jpg
# >43546491_278.jpg
# >43546498_277.jpg
# >43589709_273.jpg
# >43613495_271.jpg
# >43658697_270.jpg
# >43666348_269.jpg
# >43666374_268.jpg
# >43731790_259.jpg
# >43800409_253.jpg
# >43844395_248.jpg
# >43884526_241.jpg
# >43995921_229.jpg
# >44139659_219.jpg
# >44160940_217.jpg
# >44327195_208.jpg
# >44587730_195.jpg
# >44629805_191.jpg
# >44635255_169.jpg
# >44719426_164.jpg
# >44762813_181.jpg
# >44768358_161.jpg
# >44844142_157.jpg
# >44896088_156.jpg
# >44924962_155.jpg
# >44968085_152.jpg
# >45049555_150.jpg
# >45146907_138.jpg
# >45194036_137.jpg
# >45350055_120.jpg
# >45362713_118.jpg
# >45362925_117.jpg
# >45405774_112.jpg
# >45460142_108.jpg
# >45656572_94.jpg
# >45699323_89.jpg
# >45983997_66.jpg
# >45993968_65.jpg
# >45999361_64.jpg
# >46002091_63.jpg
# >46132776_28.jpg
# >46146691_57311.jpg
# >46221266_51135.jpg
# >46306553_43601.jpg
# >46451674_29632.jpg
# >46468915_27869.jpg
# >46501716_24381.jpg
# >46534823_20466.jpg
# >46534824_20467.jpg
# >46534825_20465.jpg
# >46534826_20468.jpg
# >46579063_15023.jpg
# >46579855_14904.jpg
# >46579856_14903.jpg
# >46594145_12957.jpg
# >46654866_3309.jpg
# >46703789_0.jpg
# >46747153_11.jpg
# >46747161_10.jpg
# >6694774_1903.jpg
# >6694777_1904.jpg
# >7116776_1883.jpg
# >British_Shorthair_10.jpg
# >British_Shorthair_100.jpg
# >British_Shorthair_103.jpg
# >British_Shorthair_104.jpg
# >British_Shorthair_106.jpg
# >British_Shorthair_110.jpg
# >British_Shorthair_111.jpg
# >British_Shorthair_115.jpg
# >British_Shorthair_118.jpg
# >British_Shorthair_120.jpg
# >British_Shorthair_123.jpg
# >British_Shorthair_124.jpg
# >British_Shorthair_125.jpg
# >British_Shorthair_126.jpg
# >British_Shorthair_130.jpg
# >British_Shorthair_134.jpg
# >British_Shorthair_135.jpg
# >British_Shorthair_136.jpg
# >British_Shorthair_139.jpg
# >British_Shorthair_140.jpg
# >British_Shorthair_148.jpg
# >British_Shorthair_151.jpg
# >British_Shorthair_153.jpg
# >British_Shorthair_154.jpg
# >British_Shorthair_155.jpg
# >British_Shorthair_159.jpg
# >British_Shorthair_160.jpg
# >British_Shorthair_161.jpg
# >British_Shorthair_162.jpg
# >British_Shorthair_164.jpg
# >British_Shorthair_166.jpg
# >British_Shorthair_169.jpg
# >British_Shorthair_17.jpg
# >British_Shorthair_170.jpg
# >British_Shorthair_172.jpg
# >British_Shorthair_173.jpg
# >British_Shorthair_175.jpg
# >British_Shorthair_178.jpg
# >British_Shorthair_179.jpg
# >British_Shorthair_180.jpg
# >British_Shorthair_182.jpg
# >British_Shorthair_183.jpg
# >British_Shorthair_185.jpg
# >British_Shorthair_188.jpg
# >British_Shorthair_189.jpg
# >British_Shorthair_190.jpg
# >British_Shorthair_193.jpg
# >British_Shorthair_195.jpg
# >British_Shorthair_196.jpg
# >British_Shorthair_198.jpg
# >British_Shorthair_2.jpg
# >British_Shorthair_200.jpg
# >British_Shorthair_204.jpg
# >British_Shorthair_209.jpg
# >British_Shorthair_21.jpg
# >British_Shorthair_210.jpg
# >British_Shorthair_218.jpg
# >British_Shorthair_22.jpg
# >British_Shorthair_223.jpg
# >British_Shorthair_239.jpg
# >British_Shorthair_241.jpg
# >British_Shorthair_248.jpg
# >British_Shorthair_263.jpg
# >British_Shorthair_268.jpg
# >British_Shorthair_271.jpg
# >British_Shorthair_273.jpg
# >British_Shorthair_274.jpg
# >British_Shorthair_278.jpg
# >British_Shorthair_28.jpg
# >British_Shorthair_3.jpg
# >British_Shorthair_30.jpg
# >British_Shorthair_32.jpg
# >British_Shorthair_36.jpg
# >British_Shorthair_37.jpg
# >British_Shorthair_43.jpg
# >British_Shorthair_45.jpg
# >British_Shorthair_46.jpg
# >British_Shorthair_49.jpg
# >British_Shorthair_55.jpg
# >British_Shorthair_57.jpg
# >British_Shorthair_6.jpg
# >British_Shorthair_61.jpg
# >British_Shorthair_62.jpg
# >British_Shorthair_63.jpg
# >British_Shorthair_70.jpg
# >British_Shorthair_71.jpg
# >British_Shorthair_75.jpg
# >British_Shorthair_77.jpg
# >British_Shorthair_78.jpg
# >British_Shorthair_79.jpg
# >British_Shorthair_8.jpg
# >British_Shorthair_83.jpg
# >British_Shorthair_88.jpg
# >British_Shorthair_90.jpg
# >British_Shorthair_91.jpg
# >British_Shorthair_92.jpg
# >British_Shorthair_96.jpg
# >British_Shorthair_97.jpg
# >British_Shorthair_99.jpg
# >gettyimages-1220573069-612x612.jpg
# >gettyimages-1220573108-612x612.jpg
# >gettyimages-1282227236-612x612.jpg
# >gettyimages-1282227255-612x612.jpg
# >gettyimages-1342064688-612x612.jpg
# >gettyimages-141382303-612x612.jpg
# >gettyimages-147514876-612x612.jpg
# >gettyimages-169602640-612x612.jpg
# >gettyimages-173180194-612x612.jpg
# >gettyimages-174178401-612x612.jpg
# >gettyimages-174180128-612x612.jpg
# >gettyimages-174185991-612x612.jpg
# >gettyimages-625086284-612x612.jpg
# >gettyimages-667587109-612x612.jpg
# >gettyimages-667587149-612x612.jpg
# >gettyimages-667587263-612x612.jpg
# >gettyimages-667587271-612x612.jpg
# >gettyimages-667587291-612x612.jpg
# >kitten-munchkin-2890491.jpg
# >Maine_Coon_105.jpg
# >Maine_Coon_106.jpg
# >Maine_Coon_109.jpg
# >Maine_Coon_115.jpg
# >Maine_Coon_123.jpg
# >Maine_Coon_124.jpg
# >Maine_Coon_128.jpg
# >Maine_Coon_129.jpg
# >Maine_Coon_13.jpg
# >Maine_Coon_131.jpg
# >Maine_Coon_132.jpg
# >Maine_Coon_133.jpg
# >Maine_Coon_134.jpg
# >Maine_Coon_138.jpg
# >Maine_Coon_139.jpg
# >Maine_Coon_14.jpg
# >Maine_Coon_144.jpg
# >Maine_Coon_146.jpg
# >Maine_Coon_151.jpg
# >Maine_Coon_152.jpg
# >Maine_Coon_157.jpg
# >Maine_Coon_158.jpg
# >Maine_Coon_159.jpg
# >Maine_Coon_160.jpg
# >Maine_Coon_162.jpg
# >Maine_Coon_168.jpg
# >Maine_Coon_169.jpg
# >Maine_Coon_17.jpg
# >Maine_Coon_176.jpg
# >Maine_Coon_180.jpg
# >Maine_Coon_184.jpg
# >Maine_Coon_187.jpg
# >Maine_Coon_189.jpg
# >Maine_Coon_19.jpg
# >Maine_Coon_194.jpg
# >Maine_Coon_196.jpg
# >Maine_Coon_197.jpg
# >Maine_Coon_2.jpg
# >Maine_Coon_204.jpg
# >Maine_Coon_205.jpg
# >Maine_Coon_206.jpg
# >Maine_Coon_214.jpg
# >Maine_Coon_219.jpg
# >Maine_Coon_222.jpg
# >Maine_Coon_238.jpg
# >Maine_Coon_241.jpg
# >Maine_Coon_245.jpg
# >Maine_Coon_246.jpg
# >Maine_Coon_25.jpg
# >Maine_Coon_266.jpg
# >Maine_Coon_268.jpg
# >Maine_Coon_272.jpg
# >Maine_Coon_28.jpg
# >Maine_Coon_33.jpg
# >Maine_Coon_35.jpg
# >Maine_Coon_36.jpg
# >Maine_Coon_38.jpg
# >Maine_Coon_39.jpg
# >Maine_Coon_41.jpg
# >Maine_Coon_42.jpg
# >Maine_Coon_43.jpg
# >Maine_Coon_44.jpg
# >Maine_Coon_49.jpg
# >Maine_Coon_50.jpg
# >Maine_Coon_52.jpg
# >Maine_Coon_53.jpg
# >Maine_Coon_57.jpg
# >Maine_Coon_61.jpg
# >Maine_Coon_64.jpg
# >Maine_Coon_7.jpg
# >Maine_Coon_76.jpg
# >Maine_Coon_77.jpg
# >Maine_Coon_78.jpg
# >Maine_Coon_80.jpg
# >Maine_Coon_83.jpg
# >Maine_Coon_84.jpg
# >Maine_Coon_92.jpg
# >Maine_Coon_93.jpg
# >Maine_Coon_94.jpg
# >Maine_Coon_97.jpg
# >Maine_Coon_98.jpg
# >munchkin-cat-2837015.jpg
# >munchkin-cat-4369756.jpg
# >munchkin-cat-4369793.jpg
# >munchkin-cat-black-background-red-standing-rearing-up-isolated-97543241.jpg
# >munchkin-cat-black-background-red-standing-rearing-up-isolated-97543366.jpg
# >munchkin-cat-black-background-red-standing-rearing-up-isolated-97543617.jpg
# >munchkin-white-black-cat-breed-64941864.jpg
# >Persian_1.jpg
# >Persian_10.jpg
# >Persian_102.jpg
# >Persian_103.jpg
# >Persian_104.jpg
# >Persian_105.jpg
# >Persian_107.jpg
# >Persian_108.jpg
# >Persian_111.jpg
# >Persian_112.jpg
# >Persian_114.jpg
# >Persian_118.jpg
# >Persian_12.jpg
# >Persian_121.jpg
# >Persian_125.jpg
# >Persian_126.jpg
# >Persian_13.jpg
# >Persian_131.jpg
# >Persian_132.jpg
# >Persian_135.jpg
# >Persian_136.jpg
# >Persian_137.jpg
# >Persian_140.jpg
# >Persian_143.jpg
# >Persian_147.jpg
# >Persian_15.jpg
# >Persian_150.jpg
# >Persian_16.jpg
# >Persian_161.jpg
# >Persian_162.jpg
# >Persian_164.jpg
# >Persian_166.jpg
# >Persian_168.jpg
# >Persian_170.jpg
# >Persian_171.jpg
# >Persian_173.jpg
# >Persian_176.jpg
# >Persian_18.jpg
# >Persian_180.jpg
# >Persian_181.jpg
# >Persian_190.jpg
# >Persian_191.jpg
# >Persian_192.jpg
# >Persian_195.jpg
# >Persian_197.jpg
# >Persian_2.jpg
# >Persian_20.jpg
# >Persian_202.jpg
# >Persian_21.jpg
# >Persian_22.jpg
# >Persian_221.jpg
# >Persian_228.jpg
# >Persian_259.jpg
# >Persian_261.jpg
# >Persian_262.jpg
# >Persian_263.jpg
# >Persian_264.jpg
# >Persian_265.jpg
# >Persian_267.jpg
# >Persian_27.jpg
# >Persian_270.jpg
# >Persian_271.jpg
# >Persian_272.jpg
# >Persian_273.jpg
# >Persian_30.jpg
# >Persian_34.jpg
# >Persian_36.jpg
# >Persian_37.jpg
# >Persian_39.jpg
# >Persian_40.jpg
# >Persian_42.jpg
# >Persian_43.jpg
# >Persian_44.jpg
# >Persian_45.jpg
# >Persian_49.jpg
# >Persian_51.jpg
# >Persian_52.jpg
# >Persian_54.jpg
# >Persian_55.jpg
# >Persian_58.jpg
# >Persian_60.jpg
# >Persian_62.jpg
# >Persian_63.jpg
# >Persian_68.jpg
# >Persian_69.jpg
# >Persian_7.jpg
# >Persian_75.jpg
# >Persian_76.jpg
# >Persian_78.jpg
# >Persian_80.jpg
# >Persian_83.jpg
# >Persian_84.jpg
# >Persian_85.jpg
# >Persian_86.jpg
# >Persian_87.jpg
# >Persian_89.jpg
# >Persian_95.jpg
# >Persian_97.jpg
# >Persian_98.jpg
# >Ragdoll_105.jpg
# >Ragdoll_106.jpg
# >Ragdoll_107.jpg
# >Ragdoll_110.jpg
# >Ragdoll_126.jpg
# >Ragdoll_127.jpg
# >Ragdoll_129.jpg
# >Ragdoll_135.jpg
# >Ragdoll_137.jpg
# >Ragdoll_138.jpg
# >Ragdoll_140.jpg
# >Ragdoll_141.jpg
# >Ragdoll_145.jpg
# >Ragdoll_146.jpg
# >Ragdoll_148.jpg
# >Ragdoll_151.jpg
# >Ragdoll_153.jpg
# >Ragdoll_154.jpg
# >Ragdoll_16.jpg
# >Ragdoll_162.jpg
# >Ragdoll_163.jpg
# >Ragdoll_169.jpg
# >Ragdoll_171.jpg
# >Ragdoll_173.jpg
# >Ragdoll_174.jpg
# >Ragdoll_176.jpg
# >Ragdoll_177.jpg
# >Ragdoll_179.jpg
# >Ragdoll_181.jpg
# >Ragdoll_182.jpg
# >Ragdoll_185.jpg
# >Ragdoll_186.jpg
# >Ragdoll_188.jpg
# >Ragdoll_189.jpg
# >Ragdoll_192.jpg
# >Ragdoll_196.jpg
# >Ragdoll_197.jpg
# >Ragdoll_202.jpg
# >Ragdoll_204.jpg
# >Ragdoll_235.jpg
# >Ragdoll_25.jpg
# >Ragdoll_250.jpg
# >Ragdoll_254.jpg
# >Ragdoll_257.jpg
# >Ragdoll_258.jpg
# >Ragdoll_26.jpg
# >Ragdoll_260.jpg
# >Ragdoll_261.jpg
# >Ragdoll_262.jpg
# >Ragdoll_263.jpg
# >Ragdoll_264.jpg
# >Ragdoll_27.jpg
# >Ragdoll_3.jpg
# >Ragdoll_32.jpg
# >Ragdoll_35.jpg
# >Ragdoll_36.jpg
# >Ragdoll_42.jpg
# >Ragdoll_43.jpg
# >Ragdoll_47.jpg
# >Ragdoll_49.jpg
# >Ragdoll_56.jpg
# >Ragdoll_57.jpg
# >Ragdoll_58.jpg
# >Ragdoll_59.jpg
# >Ragdoll_60.jpg
# >Ragdoll_67.jpg
# >Ragdoll_68.jpg
# >Ragdoll_69.jpg
# >Ragdoll_74.jpg
# >Ragdoll_75.jpg
# >Ragdoll_76.jpg
# >Ragdoll_77.jpg
# >Ragdoll_80.jpg
# >Ragdoll_83.jpg
# >Ragdoll_85.jpg
# >Ragdoll_86.jpg
# >Ragdoll_87.jpg
# >Ragdoll_9.jpg
# >Ragdoll_93.jpg
# >Ragdoll_98.jpg
# >Ragdoll_99.jpg
# Extracted Features: 1135

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text
 
filename = r'C:\Users\14059174\Desktop\FYP\Image Dataset\Cat Dataset Summary\Flickr8k.token.txt'
# load descriptions
doc = load_doc(filename)

# %%
# extract descriptions for images
def load_descriptions(doc):
	mapping = dict()
	# process lines
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		if len(line) < 2:
			continue
		# take the first token as the image id, the rest as the description
		image_id, image_desc = tokens[0], tokens[1:]
		# remove filename from image id
		image_id = image_id.split('.')[0]
		# convert description tokens back to string
		image_desc = ' '.join(image_desc)
		# create the list if needed
		if image_id not in mapping:
			mapping[image_id] = list()
		# store description
		mapping[image_id].append(image_desc)
	return mapping
 
# parse descriptions
descriptions = load_descriptions(doc)
print('Loaded: %d ' % len(descriptions))
# Out:
# Loaded: 1135

# %%
import string
 
def clean_descriptions(descriptions):
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for key, desc_list in descriptions.items():
		for i in range(len(desc_list)):
			desc = desc_list[i]
			# tokenize
			desc = desc.split()
			# convert to lower case
			desc = [word.lower() for word in desc]
			# remove punctuation from each token
			desc = [w.translate(table) for w in desc]
			# remove hanging 's' and 'a'
			desc = [word for word in desc if len(word)>1]
			# remove tokens with numbers in them
			desc = [word for word in desc if word.isalpha()]
			# store as string
			desc_list[i] =  ' '.join(desc)

# clean descriptions
clean_descriptions(descriptions)

# %%
def to_vocabulary(descriptions):
	# build a list of all description strings
	all_desc = set()
	for key in descriptions.keys():
		[all_desc.update(d.split()) for d in descriptions[key]]
	return all_desc
 
# summarize vocabulary
vocabulary = to_vocabulary(descriptions)
print('Vocabulary Size: %d' % len(vocabulary))
# Out:
# Vocabulary Size: 19

# %%
# save descriptions to file, one per line
def save_descriptions(descriptions, filename):
	lines = list()
	for key, desc_list in descriptions.items():
		for desc in desc_list:
			lines.append(key + ' ' + desc)
	data = '\n'.join(lines)
	file = open(filename, 'w')
	file.write(data)
	file.close()

save_descriptions(descriptions, 'descriptions.txt')

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text
 
# load a pre-defined list of photo identifiers
def load_set(filename):
	doc = load_doc(filename)
	dataset = list()
	# process line by line
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line.split('.')[0]
		dataset.append(identifier)
	return set(dataset)

# %%
# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document
	doc = load_doc(filename)
	descriptions = dict()
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		# split id from description
		image_id, image_desc = tokens[0], tokens[1:]
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# %%
def load_photo_features(filename, dataset):
	# load all features
	all_features = load(open(filename, 'rb'))
	# filter features
	features = {k: all_features[k] for k in dataset}
	return features

# %%
from numpy import argmax
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from pickle import load
from IPython.display import Image, display

# load training dataset (6K)
filename = r'C:\Users\14059174\Desktop\FYP\Image Dataset\Cat Dataset Summary\Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# photo features
train_features = load_photo_features('features.pkl', train)
print('Photos: train=%d' % len(train_features))
# Out:
# Dataset: 1017
# Descriptions: train=1017
# Photos: train=1017

# %%
from numpy import argmax
from pickle import load
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model
#from nltk.translate.bleu_score import corpus_bleu

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# convert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc
 
# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
	lines = to_lines(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer
 
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 22

# %%
# create sequences of images, input sequences and output words for an image
def create_sequences(tokenizer, max_length, descriptions, photos, vocab_size):
	X1, X2, y = list(), list(), list()
	# walk through each image identifier
	for key, desc_list in descriptions.items():
		# walk through each description for the image
		for desc in desc_list:
			# encode the sequence
			seq = tokenizer.texts_to_sequences([desc])[0]
			# split one sequence into multiple X,y pairs
			for i in range(1, len(seq)):
				# split into input and output pair
				in_seq, out_seq = seq[:i], seq[i]
				# pad input sequence
				in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
				# encode output sequence
				out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
				# store
				X1.append(photos[key][0])
				X2.append(in_seq)
				y.append(out_seq)
	return array(X1), array(X2), array(y)

# %%
# calculate the length of the description with the most words
def max_length(descriptions):
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)

# %%
# define the captioning model
def define_model(vocab_size, max_length):
	# feature extractor model
	inputs1 = Input(shape=(4096,))
	fe1 = Dropout(0.5)(inputs1)
	fe2 = Dense(256, activation='relu')(fe1)
	# sequence model
	inputs2 = Input(shape=(max_length,))
	se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
	se2 = Dropout(0.5)(se1)
	se3 = LSTM(256)(se2)
	# decoder model
	decoder1 = add([fe2, se3])
	decoder2 = Dense(256, activation='relu')(decoder1)
	outputs = Dense(vocab_size, activation='softmax')(decoder2)
	# tie it together [image, seq] [word]
	model = Model(inputs=[inputs1, inputs2], outputs=outputs)
	model.compile(loss='categorical_crossentropy', optimizer='adam')
	# summarize model
	print(model.summary())
	#plot_model(model, to_file='model.png', show_shapes=True)
	return model

# %%
from numpy import array
from pickle import load
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import add
from tensorflow.keras.callbacks import ModelCheckpoint

filepath = 'model-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
def max_length(descriptions):
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)

# %%
# load training dataset (6K)
filename = r'C:\Users\14059174\Desktop\FYP\Image Dataset\Cat Dataset Summary\Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# photo features
train_features = load_photo_features('features.pkl', train)
print('Photos: train=%d' % len(train_features))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)
# prepare sequences
X1train, X2train, ytrain = create_sequences(tokenizer, max_length, train_descriptions, train_features, vocab_size)
 
# dev dataset
 
# load test set
filename = r'C:\Users\14059174\Desktop\FYP\Image Dataset\Cat Dataset Summary\Flickr_8k.devImages.txt'
test = load_set(filename)
print('Dataset: %d' % len(test))
# descriptions
test_descriptions = load_clean_descriptions('descriptions.txt', test)
print('Descriptions: test=%d' % len(test_descriptions))
# photo features
test_features = load_photo_features('features.pkl', test)
print('Photos: test=%d' % len(test_features))
# prepare sequences
X1test, X2test, ytest = create_sequences(tokenizer, max_length, test_descriptions, test_features, vocab_size)
 
# fit model
 
# define the model
model = define_model(vocab_size, max_length)


# define checkpoint callback
filepath = 'model-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
# fit model
history = model.fit([X1train, X2train], ytrain, epochs=20, verbose=2, callbacks=[checkpoint], validation_data=([X1test, X2test], ytest))
# Out:
# Dataset: 1017
# Descriptions: train=1017
# Photos: train=1017
# Vocabulary Size: 22
# Description Length: 8
# Dataset: 65
# Descriptions: test=65
# Photos: test=65
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_18 (InputLayer)           [(None, 8)]          0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           [(None, 4096)]       0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 8, 256)       5632        input_18[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 4096)         0           input_17[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 8, 256)       0           embedding_6[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 256)          1048832     dropout_12[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 256)          525312      dropout_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256)          0           dense_18[0][0]
#                                                                  lstm_6[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 256)          65792       add_6[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 22)           5654        dense_19[0][0]
# ==================================================================================================
# Total params: 1,651,222
# Trainable params: 1,651,222
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 6270 samples, validate on 408 samples
# Epoch 1/20
#
# Epoch 00001: val_loss improved from inf to 0.44956, saving model to model-ep001-loss1.242-val_loss0.450.h5
# 6270/6270 - 26s - loss: 1.2425 - val_loss: 0.4496
# Epoch 2/20
#
# Epoch 00002: val_loss improved from 0.44956 to 0.31614, saving model to model-ep002-loss0.184-val_loss0.316.h5
# 6270/6270 - 17s - loss: 0.1838 - val_loss: 0.3161
# Epoch 3/20
#
# Epoch 00003: val_loss improved from 0.31614 to 0.26929, saving model to model-ep003-loss0.110-val_loss0.269.h5
# 6270/6270 - 18s - loss: 0.1099 - val_loss: 0.2693
# Epoch 4/20
#
# Epoch 00004: val_loss improved from 0.26929 to 0.22279, saving model to model-ep004-loss0.083-val_loss0.223.h5
# 6270/6270 - 18s - loss: 0.0826 - val_loss: 0.2228
# Epoch 5/20
#
# Epoch 00005: val_loss improved from 0.22279 to 0.20249, saving model to model-ep005-loss0.064-val_loss0.202.h5
# 6270/6270 - 18s - loss: 0.0636 - val_loss: 0.2025
# Epoch 6/20
#
# Epoch 00006: val_loss did not improve from 0.20249
# 6270/6270 - 17s - loss: 0.0596 - val_loss: 0.3047
# Epoch 7/20
#
# Epoch 00007: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0525 - val_loss: 0.2473
# Epoch 8/20
#
# Epoch 00008: val_loss did not improve from 0.20249
# 6270/6270 - 17s - loss: 0.0384 - val_loss: 0.3198
# Epoch 9/20
#
# Epoch 00009: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0402 - val_loss: 0.2874
# Epoch 10/20
#
# Epoch 00010: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0306 - val_loss: 0.2337
# Epoch 11/20
#
# Epoch 00011: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0341 - val_loss: 0.3168
# Epoch 12/20
#
# Epoch 00012: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0256 - val_loss: 0.2351
# Epoch 13/20
#
# Epoch 00013: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0253 - val_loss: 0.3140
# Epoch 14/20
#
# Epoch 00014: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0286 - val_loss: 0.2366
# Epoch 15/20
#
# Epoch 00015: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0257 - val_loss: 0.3732
# Epoch 16/20
#
# Epoch 00016: val_loss did not improve from 0.20249
# 6270/6270 - 14s - loss: 0.0277 - val_loss: 0.4161
# Epoch 17/20
#
# Epoch 00017: val_loss did not improve from 0.20249
# 6270/6270 - 21s - loss: 0.0411 - val_loss: 0.3198
# Epoch 18/20
#
# Epoch 00018: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0241 - val_loss: 0.3218
# Epoch 19/20
#
# Epoch 00019: val_loss did not improve from 0.20249
# 6270/6270 - 18s - loss: 0.0189 - val_loss: 0.3021
# Epoch 20/20
#
# Epoch 00020: val_loss did not improve from 0.20249
# 6270/6270 - 19s - loss: 0.0212 - val_loss: 0.3517

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None
 
# generate a description for an image
def generate_desc(model, tokenizer, photo, max_length):
	# seed the generation process
	in_text = 'startseq'
	# iterate over the whole length of the sequence
	for i in range(max_length):
		# integer encode input sequence
		sequence = tokenizer.texts_to_sequences([in_text])[0]
		# pad input
		sequence = pad_sequences([sequence], maxlen=max_length)
		# predict next word
		yhat = model.predict([photo,sequence], verbose=0)
		# convert probability to integer
		yhat = argmax(yhat)
		# map integer to word
		word = word_for_id(yhat, tokenizer)
		# stop if we cannot map the word
		if word is None:
			break
		# append as input for generating the next word
		in_text += ' ' + word
		# stop if we predict the end of the sequence
		if word == 'endseq':
			break
	return in_text

# %%
def evaluate_model(model, descriptions, photos, tokenizer, max_length):
	actual, predicted = list(), list()
	# step over the whole set
	for key, desc_list in descriptions.items():
		# generate description
		yhat = generate_desc(model, tokenizer, photos[key], max_length)
		# store actual and predicted
		references = [d.split() for d in desc_list]
		actual.append(references)
		predicted.append(yhat.split())
	# calculate BLEU score
	#print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	#print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	#print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	#print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# %%
from tensorflow.keras.models import load_model
# calculate the length of the description with the most words
def max_length(descriptions):
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)
 
# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None


# load training dataset (6K)
filename = r'C:\Users\14059174\Desktop\FYP\Image Dataset\Cat Dataset Summary\Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)
 
# prepare test set
 
# load test set
filename = r'C:\Users\14059174\Desktop\FYP\Image Dataset\Cat Dataset Summary\Flickr_8k.testImages.txt'
test = load_set(filename)
print('Dataset: %d' % len(test))
# descriptions
test_descriptions = load_clean_descriptions('descriptions.txt', test)
print('Descriptions: test=%d' % len(test_descriptions))
# photo features
test_features = load_photo_features('features.pkl', test)
print('Photos: test=%d' % len(test_features))
 
# load the model
filename = 'model-ep004-loss0.075-val_loss0.210.h5'
model = load_model(filename)
# evaluate model
evaluate_model(model, test_descriptions, test_features, tokenizer, max_length)
# Out:
# Dataset: 1017
# Descriptions: train=1017
# Vocabulary Size: 22
# Description Length: 8
# Dataset: 77
# Descriptions: test=77
# Photos: test=77
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-231-ea57d9123b44> in <module>
#      43 # load the model
#      44 filename = 'model-ep004-loss0.075-val_loss0.210.h5'
# ---> 45 model = load_model(filename)
#      46 # evaluate model
#      47 evaluate_model(model, test_descriptions, test_features, tokenizer, max_length)
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     164     if model_config is None:
#     165       raise ValueError('No model found in config file.')
# --> 166     model_config = json.loads(model_config.decode('utf-8'))
#     167     model = model_config_lib.model_from_config(model_config,
#     168                                                custom_objects=custom_objects)
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from pickle import dump

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load a pre-defined list of photo identifiers
def load_set(filename):
	doc = load_doc(filename)
	dataset = list()
	# process line by line
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line.split('.')[0]
		dataset.append(identifier)
	return set(dataset)

# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document
	doc = load_doc(filename)
	descriptions = dict()
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		# split id from description
		image_id, image_desc = tokens[0], tokens[1:]
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# covert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc

# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
	lines = to_lines(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# load training dataset (6K)
filename = r'C:\Users\14059174\Desktop\FYP\Image Dataset\Cat Dataset Summary\Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
# save the tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))

# %%
from pickle import load
from numpy import argmax
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
 
# extract features from each photo in the directory
def extract_features(filename):
	# load the model
	model = VGG16()
	# re-structure the model
	model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
	# load the photo
	image = load_img(filename, target_size=(224, 224))
	# convert the image pixels to a numpy array
	image = img_to_array(image)
	# reshape data for the model
	image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
	# prepare the image for the VGG model
	image = preprocess_input(image)
	# get features
	feature = model.predict(image, verbose=0)
	return feature
 
# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None
 
# generate a description for an image
def generate_desc(model, tokenizer, photo, max_length):
	# seed the generation process
	in_text = 'startseq'
	# iterate over the whole length of the sequence
	for i in range(max_length):
		# integer encode input sequence
		sequence = tokenizer.texts_to_sequences([in_text])[0]
		# pad input
		sequence = pad_sequences([sequence], maxlen=max_length)
		# predict next word
		yhat = model.predict([photo,sequence], verbose=0)
		# convert probability to integer
		yhat = argmax(yhat)
		# map integer to word
		word = word_for_id(yhat, tokenizer)
		# stop if we cannot map the word
		if word is None:
			break
		# append as input for generating the next word
		in_text += ' ' + word
		# stop if we predict the end of the sequence
		if word == 'endseq':
			break
	return in_text
 
# load the tokenizer
tokenizer = load(open('tokenizer.pkl', 'rb'))
# pre-define the max sequence length (from training)
max_length = 8
# load the model
model = load_model('model-ep005-loss0.071-val_loss0.210.h5')
# load and prepare the photograph
photo = extract_features(r'C:\Users\14059174\Desktop\CatExample\munch.jpg')
# generate description
description = generate_desc(model, tokenizer, photo, max_length)
display(Image(filename= r'C:\Users\14059174\Desktop\CatExample\munch.jpg'))
print(description)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-172-710bfc704490> in <module>
#      65 max_length = 8
#      66 # load the model
# ---> 67 model = load_model('model-ep005-loss0.071-val_loss0.210.h5')
#      68 # load and prepare the photograph
#      69 photo = extract_features(r'C:\Users\14059174\Desktop\CatExample\munch.jpg')
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     164     if model_config is None:
#     165       raise ValueError('No model found in config file.')
# --> 166     model_config = json.loads(model_config.decode('utf-8'))
#     167     model = model_config_lib.model_from_config(model_config,
#     168                                                custom_objects=custom_objects)
#
# AttributeError: 'str' object has no attribute 'decode'

# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt


labels = pd.read_csv(r'C:\Users\14059174\Desktop\FYP\Image Dataset\DogImage3\labels4.csv')
labels.isnull().values.any()
labels.describe(include="all")
# Out:
#                          Id                breed
# count                  3181                 3181
# unique                 3181                   55
# top     Affenpinscher_00010  Miniature_schnauzer
# freq                      1                  149

# %%
breed_counts = pd.pivot_table(labels, index=['breed'], aggfunc='count')
breed_counts = breed_counts.sort_values("Id", ascending=False)
breed_counts = breed_counts.rename(columns = {"id" : "count"})
breed_counts.head()
# Out:
#                        Id
# breed
# Miniature_schnauzer   149
# Norfolk_Terrier        90
# JapaneseSpitz          80
# Siberian_husky         79
# Jack_Russell_Terrier   78

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,18)
sns.set_style("whitegrid")
ax = sns.barplot(x = breed_counts['Id'], y = breed_counts.index, data = labels)
ax.set_yticklabels(ax.get_yticklabels(), fontsize = 12)
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)
ax.set(xlabel='Count',ylabel='Dog Breed')
ax.set_title('Distribution of Dog breeds')
# Out:
# Text(0.5, 1.0, 'Distribution of Dog breeds')

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,21)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1,21)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
hhh
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-170-c8bb0f7e5842> in <module>
# ----> 1 loss_train = history.history['accuracy']
#       2 loss_val = history.history['val_accuracy']
#       3 epochs = range(1,21)
#       4 plt.plot(epochs, loss_train, 'g', label='Training accuracy')
#       5 plt.plot(epochs, loss_val, 'b', label='validation accuracy')
#
# KeyError: 'accuracy'
